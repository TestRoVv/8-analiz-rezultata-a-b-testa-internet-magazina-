# %% [markdown]
# Михаил, привет! Меня зовут Ирина Литвинова. Сегодня я проверю твой проект.<br>
# <br> Ты можешь обращаться ко мне на "ты"😏 Надеюсь, ты не будешь против, если и я буду обращаться к тебе на "ты". Но если для тебя это неприемлeмо, дай знать, пожалуйста) <br>
# <br> Мне очень важна твоя реакция на мои комментарии, особенно <font color='red'>красные</font>. Можешь реагировать, например, так ('исправлено', 'не понятно как исправить ошибку', ...)<br>
# <br> Ты можешь реагировать на мои комментарии своими, выделяя их цветами и наиболее понравившимся тебе способом оформления, но явно  отличающимся от моих комментариев. <br>
# Это нужно, чтобы не создавалась путаница😉<br>
# Например, так:<br>
#
# <div class="alert alert-block alert-info"><b>Комментарий студента</b>
#
# <b>Изменения:</b> Были внесены следующие изменения ...<br></div>
#
#
# <br> Пожалуйста, не удаляй мои комментарии, так как они повышают качество повторного ревью и делают его быстрее)<br>
# <br> Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самостоятельно найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓<br>
#
# Для твоего удобства мои комментарии будут в <font color='green'>зеленой</font>, <font color='orange'>желтой</font> или <font color='red'>красной</font> рамках:<br>
# <br>
#
# <div class="alert alert-block alert-danger"><b>Комментарий ревьюера</b>
#
# <b>Ошибка:</b><br>
# Если требуются исправления. Работа не может быть принята с красными комментариями.<br></div>
#
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Если можно немного улучшить.<br></div>
#
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
# Если все сделано отлично.<br></div>

# %% [markdown]
# <div class="alert alert-success"><div class='alert btn-success'>
# Михаил, 😊буду рада, если смогла быть тебе полезной!)<br>
# Спасибо, что внес необходимые корректировки сразу, отреагировал на желтые комментарии и за креатив)<br>
# А я, в свою очередь, с удовольствием принимаю проект!<br>
#
#
# **И желаю тебе удачи в дальнейшей учебе!**😉 </div></div>

# %% [markdown]
# # Анализ результата A/B-теста интернет-магазина.

# %% [markdown]
# Вы — аналитик крупного интернет-магазина. Вместе с отделом маркетинга вы подготовили список гипотез для увеличения выручки.
# Приоритизируйте гипотезы, запустите A/B-тест и проанализируйте результаты.

# %% [markdown]
# ## Изучение данных

# %% [markdown]
# ### Описание проекта

# %% [markdown]
# #### Часть 1. Приоритизация гипотез.

# %% [markdown]
# В файле */datasets/hypothesis.csv* 9 гипотез по увеличению выручки интернет-магазина с указанными параметрами Reach, Impact, Confidence, Effort.

# %% [markdown]
# **Задача**
#
# * Примените фреймворк ICE для приоритизации гипотез. Отсортируйте их по убыванию приоритета.
# * Примените фреймворк RICE для приоритизации гипотез. Отсортируйте их по убыванию приоритета.
# * Укажите, как изменилась приоритизация гипотез при применении RICE вместо ICE. Объясните, почему так произошло.

# %% [markdown]
# #### Часть 2. Анализ A/B-теста.

# %% [markdown]
# Вы провели A/B-тест и получили результаты, которые описаны в файлах */datasets/orders.csv* и */datasets/visitors.csv*.

# %% [markdown]
# **Задача**
#
# Проанализируйте A/B-тест:
#
# * Постройте график кумулятивной выручки по группам. Сделайте выводы и предположения.
# * Постройте график кумулятивного среднего чека по группам. Сделайте выводы и предположения.
# * Постройте график относительного изменения кумулятивного среднего чека группы B к группе A. Сделайте выводы и предположения.
# * Постройте график кумулятивной конверсии по группам. Сделайте выводы и предположения.
# * Постройте график относительного изменения кумулятивной конверсии группы B к группе A. Сделайте выводы и предположения.
# * Постройте точечный график количества заказов по пользователям. Сделайте выводы и предположения.
# * Посчитайте 95-й и 99-й перцентили количества заказов на пользователя. Выберите границу для определения аномальных пользователей.
# * Постройте точечный график стоимостей заказов. Сделайте выводы и предположения.
# * Посчитайте 95-й и 99-й перцентили стоимости заказов. Выберите границу для определения аномальных заказов.
# * Посчитайте статистическую значимость различий в конверсии между группами по «сырым» данным. Сделайте выводы и предположения.
# * Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделайте выводы и предположения.
# * Посчитайте статистическую значимость различий в конверсии между группами по «очищенным» данным. Сделайте выводы и предположения.
# * Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделайте выводы и предположения.
# * Примите решение по результатам теста и объясните его. Варианты решений:
#      1. Остановить тест, зафиксировать победу одной из групп.
#      2. Остановить тест, зафиксировать отсутствие различий между группами.
#      3. Продолжить тест.

# %% [markdown]
# ### Описание данных

# %% [markdown]
# Файл */datasets/hypothesis.csv*
# * Hypothesis — краткое описание гипотезы;
# * Reach — охват пользователей по 10-балльной шкале;
# * Impact — влияние на пользователей по 10-балльной шкале;
# * Confidence — уверенность в гипотезе по 10-балльной шкале;
# * Efforts — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение Efforts, тем дороже проверка гипотезы.
#
# Файл */datasets/orders.csv*
# * transactionId — идентификатор заказа;
# * visitorId — идентификатор пользователя, совершившего заказ;
# * date — дата, когда был совершён заказ;
# * revenue — выручка заказа;
# * group — группа A/B-теста, в которую попал заказ.
#
# Файл */datasets/visitors.csv*
# * date — дата;
# * group — группа A/B-теста;
# * visitors — количество пользователей в указанную дату в указанной группе A/B-теста

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
# 👍 Хорошо, что есть введение в проект и описание данных.<br>
#
# </div>

# %% [markdown]
# ### Цель исследования:

# %% [markdown]
# ### Ход исследования

# %% [markdown]
# ## Загрузка данных и подготовка их к анализу

# %% [markdown]
# Используемые библиотеки:

# %%
import pandas as pd # импорт библиотеки pandas
from datetime import datetime, timedelta
from scipy import stats as st
import matplotlib.pyplot as plt 
pd.set_option('display.max_columns', None) # Сброс ограничений на число столбцов
import warnings
warnings.simplefilter('ignore')
import numpy as np
import math
import seaborn as sns
sns.set(color_codes=True)
from plotly.offline import init_notebook_mode, iplot
import plotly
import plotly.graph_objs as go
import datetime as dt
import scipy.stats as stats

# %% [markdown]
# Пересохраняем таблицы:

# %%
hypothesis = pd.read_csv('/datasets/hypothesis.csv')
orders = pd.read_csv('/datasets/orders.csv')
visitors = pd.read_csv('/datasets/visitors.csv')

# %%
display(hypothesis.head())
display(orders.head())
display(visitors.head())
# Out:
#                                           Hypothesis  Reach  Impact  \
# 0  Добавить два новых канала привлечения трафика,...      3      10
# 1  Запустить собственную службу доставки, что сок...      2       5
# 2  Добавить блоки рекомендаций товаров на сайт ин...      8       3
# 3  Изменить структура категорий, что увеличит кон...      8       3
# 4  Изменить цвет фона главной страницы, чтобы уве...      3       1
#
#    Confidence  Efforts
# 0           8        6
# 1           4       10
# 2           7        3
# 3           3        8
# 4           1        1
#    transactionId   visitorId        date  revenue group
# 0     3667963787  3312258926  2019-08-15     1650     B
# 1     2804400009  3642806036  2019-08-15      730     B
# 2     2961555356  4069496402  2019-08-15      400     A
# 3     3797467345  1196621759  2019-08-15     9759     B
# 4     2282983706  2322279887  2019-08-15     2308     B
#          date group  visitors
# 0  2019-08-01     A       719
# ...

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# Проверяем таблицы на дубликаты и пропуски, приводим все столбцы к нижнему регистру.

# %%
def checking_columns(df):
    for g in df.columns:
        df.columns = df.columns.str.replace(g,g.lower())


    for h in df.columns:
        df.columns = df.columns.str.replace(' ', '_')

    #df.info()
    print()
    print(df.columns) # проверка названия столбца
    print()
    print('Дубликаты:',df.duplicated().sum())
    print()
    for row in df:
        print(df[row].head(0)) # вывод названия столбца и типа данных
        print(df[row].sort_values().unique()) # вывод уникальных значений
        #print(df[row].describe())
        print('Пропуски:',df[row].isna().sum()) # подсчет пропущенных значений
        print()
        print()

# %%
checking_columns(hypothesis)
# Out:
# Index(['hypothesis', 'reach', 'impact', 'confidence', 'efforts'], dtype='object')
#
# Дубликаты: 0
#
# Series([], Name: hypothesis, dtype: object)
# ['Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа'
#  'Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей'
#  'Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов'
#  'Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок'
#  'Запустить акцию, дающую скидку на товар в день рождения'
#  'Запустить собственную службу доставки, что сократит срок доставки заказов'
#  'Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар'
#  'Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей'
# ...

# %%
checking_columns(orders)
# Out:
# Index(['transactionid', 'visitorid', 'date', 'revenue', 'group'], dtype='object')
#
# Дубликаты: 0
#
# Series([], Name: transactionid, dtype: int64)
# [   1062393    4919758    7210578 ... 4281129020 4288552432 4293855558]
# Пропуски: 0
#
#
# Series([], Name: visitorid, dtype: int64)
# [   5114589    6958315    8300375 ... 4279090005 4281247801 4283872382]
# Пропуски: 0
#
#
# Series([], Name: date, dtype: object)
# ['2019-08-01' '2019-08-02' '2019-08-03' '2019-08-04' '2019-08-05'
#  '2019-08-06' '2019-08-07' '2019-08-08' '2019-08-09' '2019-08-10'
#  '2019-08-11' '2019-08-12' '2019-08-13' '2019-08-14' '2019-08-15'
#  '2019-08-16' '2019-08-17' '2019-08-18' '2019-08-19' '2019-08-20'
#  '2019-08-21' '2019-08-22' '2019-08-23' '2019-08-24' '2019-08-25'
#  '2019-08-26' '2019-08-27' '2019-08-28' '2019-08-29' '2019-08-30'
#  '2019-08-31']
# Пропуски: 0
#
#
# Series([], Name: revenue, dtype: int64)
# [     50      60      70      75      76      90     100     110     112
# ...

# %%
checking_columns(visitors)
# Out:
# Index(['date', 'group', 'visitors'], dtype='object')
#
# Дубликаты: 0
#
# Series([], Name: date, dtype: object)
# ['2019-08-01' '2019-08-02' '2019-08-03' '2019-08-04' '2019-08-05'
#  '2019-08-06' '2019-08-07' '2019-08-08' '2019-08-09' '2019-08-10'
#  '2019-08-11' '2019-08-12' '2019-08-13' '2019-08-14' '2019-08-15'
#  '2019-08-16' '2019-08-17' '2019-08-18' '2019-08-19' '2019-08-20'
#  '2019-08-21' '2019-08-22' '2019-08-23' '2019-08-24' '2019-08-25'
#  '2019-08-26' '2019-08-27' '2019-08-28' '2019-08-29' '2019-08-30'
#  '2019-08-31']
# Пропуски: 0
#
#
# Series([], Name: group, dtype: object)
# ['A' 'B']
# Пропуски: 0
#
#
# Series([], Name: visitors, dtype: int64)
# [361 369 378 395 406 412 413 421 468 487 490 502 507 509 531 543 544 546
#  560 575 577 581 594 595 609 610 617 619 621 628 644 646 650 654 655 656
#  667 668 676 679 699 707 709 711 713 717 718 719 720 721 722 735 737 746
#  748 756 769 770]
# Пропуски: 0

# %% [markdown]
# ###  Изменяем типы дат.

# %%
orders['date']= pd.to_datetime(orders['date'], format='%Y-%m-%d')
visitors['date']= pd.to_datetime(visitors['date'], format='%Y-%m-%d')
#costs['dt']=pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# ### Полученные данные для анализа

# %%
print('Таблица hypothesis (Таблица гипотез):')
display(hypothesis.head())
print()
hypothesis.info()
print()
print()
print()
print('Таблица orders (Таблица заказов):')
display(orders.head())
print()
orders.info()
print()
print()
print()
print('Таблица visitors (Таблица пользователей):')
display(visitors.head())
print()
visitors.info()
# Out:
# Таблица hypothesis (Таблица гипотез):
#                                           hypothesis  reach  impact  \
# 0  Добавить два новых канала привлечения трафика,...      3      10
# 1  Запустить собственную службу доставки, что сок...      2       5
# 2  Добавить блоки рекомендаций товаров на сайт ин...      8       3
# 3  Изменить структура категорий, что увеличит кон...      8       3
# 4  Изменить цвет фона главной страницы, чтобы уве...      3       1
#
#    confidence  efforts
# 0           8        6
# 1           4       10
# 2           7        3
# 3           3        8
# 4           1        1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hypothesis  9 non-null      object
#  1   reach       9 non-null      int64
#  2   impact      9 non-null      int64
#  3   confidence  9 non-null      int64
# ...

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
# 👍 Необходимая предобработка проведена.<br>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Здесь можно провести еще дополнительные исследования:  <br>
# * сколько у нас групп в АВ-тесте  в датафреймах;
# * даты начала и окончания теста в датафреймах;
#
#
#
# </div>

# %% [markdown]
# ## Приоритизация гипотез.

# %% [markdown]
# *Проверка гипотез чаще всего стоит дорого, а ресурсов не хватает. Придётся выбрать, что будем тестировать, а чему скажем «нет». Чтобы максимизировать ожидаемое улучшение ключевых метрик бизнеса, сформулированные гипотезы приоритизируют.*

# %% [markdown]
# ### Фреймворк ICE

# %% [markdown]
# *ICE (от англ. impact, confidence, effort / ease «влияние, уверенность, усилия / простота») — один из самых популярных способов приоритизации задач*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pd.options.display.max_colwidth = 100
# Воспользуемся 2-й формулой.
hypothesis['ice'] = (hypothesis['impact']*hypothesis['confidence'])/hypothesis['efforts']
hypothesis.sort_values(by='ice', ascending=False)
# Out:
#                                                                                             hypothesis  \
# 8                                              Запустить акцию, дающую скидку на товар в день рождения
# 0   Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7     Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6  Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конве...
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средни...
# 1                            Запустить собственную службу доставки, что сократит срок доставки заказов
# 5             Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 3  Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# ...

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍Молодец, что выводишь гипотезы отсортированные по фреймворку,<br>
# Так мы сразу видим гипотезы, которые имеют приоритет.<br>
# ice можно округлить)
# </div>

# %% [markdown]
# ### Фреймворк RICE

# %% [markdown]
# *RICE (R от англ. reach, «охват») - является модификацией ICE, где учитывается охват.*

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pd.options.display.max_colwidth = 100
hypothesis['rice'] = (hypothesis['reach']*hypothesis['impact']*hypothesis['confidence'])/hypothesis['efforts']
hypothesis.sort_values(by='rice', ascending=False)
# Out:
#                                                                                             hypothesis  \
# 7     Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средни...
# 0   Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6  Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конве...
# 8                                              Запустить акцию, дающую скидку на товар в день рождения
# 3  Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                            Запустить собственную службу доставки, что сократит срок доставки заказов
# 5             Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# Охват клиентов вносит поправки в приоритеты гипотез. При ICE топ 3 гипотезы - 8, 0 и 7. При RICE - 7, 2 и 0. Визуализируем.

# %%
y = hypothesis['ice'] 
z = hypothesis['rice'] 
n = hypothesis.index 

fig, ax = plt.subplots()
ax.scatter(z, y)

for i, txt in enumerate(n):
    ax.annotate(txt, (z[i], y[i]))

  


plt.title("ICE and RICE гипотезы") 
plt.xlabel("rice") 
plt.ylabel("ice")

fig.set_figheight(10)
fig.set_figwidth(10) 
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# **А еще можешь воспользоваться графиком для наглядности** <br>
# Он поможет выбрать наиболее перспективные гипотезы) <br>
# ```python
# y = hypothesis['ICE']
# z = hypothesis['RICE']
# n = hypothesis.index
#
# fig, ax = plt.subplots()
# ax.scatter(z, y)
#
# for i, txt in enumerate(n):
#     ax.annotate(txt, (z[i], y[i]))
#
# plt.title("ICE and RICE гипотезы")
# plt.xlabel("RICE")
# plt.ylabel("ICE");
# ```
# </div>

# %% [markdown]
# ## Анализ A/B-теста

# %% [markdown]
# *Чтобы построить графики, нужно собрать кумулятивные данные.*

# %% [markdown]
# Создаем массив уникальных пар значений дат и групп теста.

# %%
datesGroups = orders[['date','group']].drop_duplicates()

# %% [markdown]
# Соберём агрегированные кумулятивные по дням данные о заказах.
#
# Агрегируем значения. Вычислим максимальную дату. Для группы тоже рассчитаем максимум. Найдём число уникальных ID заказов и пользователей. Подсчитаем сумму средних чеков.

# %%
ordersAggregated = datesGroups.apply(lambda x: orders[np.logical_and(orders['date'] <= x['date'], orders['group'] == x['group'])]\
.agg({'date' : 'max', 'group' : 'max', 'transactionid' : 'nunique', 'visitorid' : 'nunique', 'revenue' : 'sum'}), axis=1).sort_values(by=['date','group'])

# %% [markdown]
# *ежедневные результаты тестирования до выбранного дня включительно*

# %%
ordersAggregated.head()
# Out:
#           date group  transactionid  visitorid  revenue
# 55  2019-08-01     A             24         20   148579
# 66  2019-08-01     B             21         20   101217
# 175 2019-08-02     A             44         38   242401
# 173 2019-08-02     B             45         43   266748
# 291 2019-08-03     A             68         62   354874

# %% [markdown]
# Аналогично получим агрегированные кумулятивные по дням данные о посетителях

# %%
visitorsAggregated = datesGroups.apply(lambda x: visitors[np.logical_and(visitors['date'] <= x['date'], visitors['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'visitors' : 'sum'}), axis=1).sort_values(by=['date','group'])

# %%
visitorsAggregated.head()
# Out:
#           date group  visitors
# 55  2019-08-01     A       719
# 66  2019-08-01     B       713
# 175 2019-08-02     A      1338
# 173 2019-08-02     B      1294
# 291 2019-08-03     A      1845

# %% [markdown]
# Объединим обе таблицы в одну с понятными названиями столбцов:

# %%
cumulativeData = ordersAggregated.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulativeData.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

# %%
cumulativeData
# Out:
#          date group  orders  buyers  revenue  visitors
# 0  2019-08-01     A      24      20   148579       719
# 1  2019-08-01     B      21      20   101217       713
# 2  2019-08-02     A      44      38   242401      1338
# 3  2019-08-02     B      45      43   266748      1294
# 4  2019-08-03     A      68      62   354874      1845
# ..        ...   ...     ...     ...      ...       ...
# 57 2019-08-29     B     596     544  5559398     17708
# 58 2019-08-30     A     545     493  4022970     18037
# 59 2019-08-30     B     620     567  5774631     18198
# 60 2019-08-31     A     557     503  4084803     18736
# 61 2019-08-31     B     640     586  5907760     18916
#
# [62 rows x 6 columns]

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Здесь можно проверить, корректно ли был содан датафрейм cummulativeData. Совпадают ли минимальная и максимальная даты в этом датафрейме с минимальной и максимальной датой в исходных данных. <br>
#
#
# </div>

# %% [markdown]
# ### График кумулятивной выручки по группам

# %%
# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
cumulativeRevenueA = cumulativeData[cumulativeData['group']=='A'][['date','revenue', 'orders']]

# %%
# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
cumulativeRevenueB = cumulativeData[cumulativeData['group']=='B'][['date','revenue', 'orders']]

# %%
plt.figure(figsize=(12, 7))
# Строим график выручки группы А
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')
# Строим график выручки группы B
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')

plt.title('График кумулятивной выручки по группам', size = 15)
plt.xticks(rotation=90)
plt.legend() 
plt.show()

# %% [markdown]
# Выручка увеличивается в течение всего теста. Группа А растет постепенно, в то время как в группе В есть резкий рост в промежутке 17.08 - 21.08. Это сигнализирует о всплесках числа заказов, либо о появлении очень дорогих заказов в выборке.

# %% [markdown]
# ### График кумулятивного среднего чека по группам

# %%
plt.figure(figsize=(12, 7))
# Строим график среднего чек группы А
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue']/cumulativeRevenueA['orders'], label='A')
# Строим график среднего чек группы B
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue']/cumulativeRevenueB['orders'], label='B')

plt.title('График кумулятивной выручки по группам', size = 15)
plt.xticks(rotation=90)
plt.legend() 
plt.show()

# %% [markdown]
# Средний чек увеличивается в течение всего теста. Однако, имеются имеются крупные чеки по каждой из групп (резкий рост на графике). Особенно выделяется группа В.

# %% [markdown]
# ### График относительного изменения кумулятивного среднего чека группы B к группе A.

# %%
# собираем данные в одном датафрейме
mergedCumulativeRevenue = cumulativeRevenueA.merge(cumulativeRevenueB, left_on='date', right_on='date', how='left', suffixes=['A', 'B'])

# %%
plt.figure(figsize=(12, 7))
# cтроим отношение средних чеков
plt.plot(mergedCumulativeRevenue['date'], (mergedCumulativeRevenue['revenueB']/mergedCumulativeRevenue['ordersB'])/(mergedCumulativeRevenue['revenueA']/mergedCumulativeRevenue['ordersA'])-1)

# добавляем ось X
plt.axhline(y=0, color='r', linestyle='--') 
plt.title('График относительного изменения кумулятивного среднего чека группы B к группе A', size = 15)
plt.xticks(rotation=90)
plt.legend('')
plt.show()

# %% [markdown]
# В нескольких точках график различия показывает, что и в начале теста есть аномальные чеки.

# %% [markdown]
# ### График кумулятивной конверсии по группам.

# %%
# считаем кумулятивную конверсию
cumulativeData['conversion'] = cumulativeData['orders']/cumulativeData['visitors']

# %%
# отделяем данные по группе A
cumulativeDataA = cumulativeData[cumulativeData['group']=='A']
# отделяем данные по группе B
cumulativeDataB = cumulativeData[cumulativeData['group']=='B']

# %%
plt.figure(figsize=(12, 7))
# строим графики
plt.plot(cumulativeDataA['date'], cumulativeDataA['conversion'], label='A')
plt.plot(cumulativeDataB['date'], cumulativeDataB['conversion'], label='B')

# задаем масштаб осей
plt.axis([cumulativeDataA['date'].min()-timedelta(1), cumulativeDataA['date'].max()+timedelta(1), 0, 0.04])
plt.title(' График кумулятивной конверсии по группам', size = 15)
plt.ylim((0.025,None))
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# Группы колебались в начале,но затем конверсия группы В вырвалась вперёд и зафиксировалась, конверсия группы А просела. Симметрично с большой натяжкой, после 18.08 числа.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍 Выводы по каждому пункту верные!
#
# </div>

# %% [markdown]
# ### График относительного изменения кумулятивной конверсии группы B к группе A.

# %%
mergedCumulativeConversions = cumulativeDataA[['date','conversion']].merge(cumulativeDataB[['date','conversion']], left_on='date', right_on='date', how='left', suffixes=['A', 'B'])

# %%
plt.figure(figsize=(12, 7))

plt.plot(mergedCumulativeConversions['date'],
         mergedCumulativeConversions['conversionB']/mergedCumulativeConversions['conversionA']-1,
         label="Относительный прирост конверсии группы B относительно группы A")
#plt.legend()
plt.title('График относительного изменения кумулятивной конверсии группы B к группе A', size = 15)
plt.axhline(y=0, color='black', linestyle='--')
plt.axhline(y=0.1, color='grey', linestyle='--')
plt.xticks(rotation=90)
plt.axis([mergedCumulativeConversions['date'].min()-timedelta(1), mergedCumulativeConversions['date'].max()+timedelta(1), -0.5, 0.5])
plt.show()

# %% [markdown]
# В начале теста группа B взяла разгон и стабильно опережает группу А. Конец недели показывает просадку, что еще раз говорит о влиянии аномалий.

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
#
# Обрати внимание, если мы зададим y= 0.1, то увидим, что конверсия группы B стабильно выше.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Комментарий студента</b>
#
# <b>Изменения:</b> Исправил)) <br></div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера V-2</b>
#
# <b>Успех:</b><br>
#     👍Так-то лучше   😉
# </div>

# %% [markdown]
# ### Точечный график количества заказов по пользователям

# %%
#сгруппирует заказы по пользователям
ordersByUsers = (
    orders.groupby('visitorid', as_index=False)
    .agg({'transactionid': 'nunique'})
)

# %%
#подсчитает число уникальных заказов по сгруппированным данным
ordersByUsers.columns = ['visitorid', 'transactionid']

# %%
ordersByUsers.sort_values(by='transactionid', ascending=False).head(10)
# Out:
#        visitorid  transactionid
# 1023  4256040402             11
# 591   2458001652             11
# 569   2378935119              9
# 487   2038680547              8
# 44     199603092              5
# 744   3062433592              5
# 55     237748145              5
# 917   3803269165              5
# 299   1230306981              5
# 897   3717692402              5

# %% [markdown]
# Есть пользователи, которые совершали 5, 8, 9 и 11 заказов. Значительно больше, чем обычный пользователь за неделю.

# %%
plt.figure(figsize=(12, 7))
plt.hist(ordersByUsers['transactionid']) 
plt.title('Гистограмма количества заказов по пользователям', size = 15)
plt.show()

# %% [markdown]
# Большинство покупателей заказывали только один раз. Однако доля пользователей с 2-4 заказами тоже значительна.

# %%
plt.figure(figsize=(12, 7))
# серия из чисел от 0 до количества наблюдений в ordersByUsers
x_values = pd.Series(range(0, len(ordersByUsers)))
plt.title('Точечный график количества заказов по пользователям', size=15)
plt.scatter(x_values, ordersByUsers['transactionid']) 

range_i = []
for i in range(ordersByUsers['transactionid'].max()+1):
    range_i.append(i)

plt.yticks(range_i)
plt.show()

# %% [markdown]
# Выводы подтверждаются: много пользователей с 2-4 заказами. Их точная доля не ясна — непонятно, считать их аномалиями или нет.

# %% [markdown]
# ### 95-й и 99-й перцентили количества заказов на пользователя.

# %%
print(np.percentile(ordersByUsers['transactionid'], [95, 99]))
# Out:
# [2. 4.]

# %% [markdown]
# Не более 5% совершали более двух заказов. И не более 1% пользователей - больше четырех заказов.

# %% [markdown]
# ### Точечный график стоимостей заказов

# %%
plt.figure(figsize=(12, 7))
plt.hist(orders['revenue'])
plt.title('Гистограмма распределения стоимостей заказов', size = 15)
plt.show()

# %% [markdown]
# Сумма большинства заказов не превышает 200000

# %%
plt.figure(figsize=(12, 7))
orders_a = orders[orders['group']=='A']
orders_b = orders[orders['group']=='B']

x_a_values = pd.Series(range(0, len(orders_a['revenue'])))
x_b_values = pd.Series(range(0, len(orders_b['revenue'])))

plt.scatter(x_a_values, orders_a['revenue'],alpha = 0.5,color='blue',label='A') 
plt.scatter(x_b_values, orders_b['revenue'],alpha = 0.3,color='orange',label='B') 
plt.title('Точечный график стоимостей заказов', size = 15)
plt.legend()
plt.show()

# %% [markdown]
# Точечный график подтверждает, что у группы В средний чек и выручка увеличивается за счет одного заказа. Построим дополнительный график.

# %%
plt.figure(figsize=(12, 7))
orders_a = orders[orders['group']=='A']
orders_b = orders[orders['group']=='B']

x_a_values = pd.Series(range(0, len(orders_a['revenue'])))
x_b_values = pd.Series(range(0, len(orders_b['revenue'])))

plt.scatter(x_a_values, orders_a['revenue'],alpha = 0.5,color='blue',label='A') 
plt.scatter(x_b_values, orders_b['revenue'],alpha = 0.5,color='orange',label='B') 
plt.title('Точечный график стоимостей заказов', size = 15)
plt.ylim((0,60000))
plt.legend()
plt.show()

# %% [markdown]
# Дополнительный график показывает, что большинство пользователей находятся в диапозоне до 10000.

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Здесь еще можно построить дополнительный график стоимостей заказов, ограничив значение по оси Y . Чтобы лучше рассмотреть закономерность.<br>
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Комментарий студента</b>
#
# <b>Изменения:</b> Добавил)) <br></div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера V-2</b>
#
# <b>Успех:</b><br>
#     👍Отлично!
# </div>

# %% [markdown]
# ### 95-й и 99-й перцентили стоимости заказов.

# %%
print(np.percentile(orders['revenue'], [95, 99]))
# Out:
# [28000.  58233.2]

# %% [markdown]
# Не более, чем у 5% заказов чек дороже 28000. И не больше, чем у 1% заказов - дороже 58234.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍 Молодец, что рассчитываешь по percentile!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Комментарий студента</b>
#
# <b> ![image.png](attachment:image.png) <br></div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера V-2</b>
#
# <b>Успех:</b><br>
#     👍Классная картинка! Позаимствую😜
# </div>

# %% [markdown]
# # **Cтатистическая значимость**

# %% [markdown]
# Подготовим данные.

# %% [markdown]
# Количество пользователей ежедневно по группе А и по группе В.

# %%
visitorsADaily = visitors[visitors['group'] == 'A'][['date', 'visitors']]
visitorsADaily.columns = ['date', 'visitorsPerDateA']

# %%
visitorsBDaily = visitors[visitors['group'] == 'B'][['date', 'visitors']]
visitorsBDaily.columns = ['date', 'visitorsPerDateB']

# %% [markdown]
# Количество пользователей до выбранной даты включительно по группе A и по группе В.

# %%
visitorsACummulative = visitorsADaily.apply(
    lambda x: visitorsADaily[visitorsADaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateA': 'sum'}
    ),
    axis=1,
)
visitorsACummulative.columns = ['date', 'visitorsCummulativeA']

# %%
visitorsBCummulative = visitorsBDaily.apply(
    lambda x: visitorsBDaily[visitorsBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateB': 'sum'}
    ),
    axis=1,
)
visitorsBCummulative.columns = ['date', 'visitorsCummulativeB']

# %% [markdown]
# Количество заказов и выручки, в выбранную дату по группе A и по группе В.

# %%
ordersADaily = (
    orders[orders['group'] == 'A'][['date', 'transactionid', 'visitorid', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transactionid': pd.Series.nunique, 'revenue': 'sum'})
)
ordersADaily.columns = ['date', 'ordersPerDateA', 'revenuePerDateA']

# %%
ordersBDaily = (
    orders[orders['group'] == 'B'][['date', 'transactionid', 'visitorid', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transactionid': pd.Series.nunique, 'revenue': 'sum'})
)
ordersBDaily.columns = ['date', 'ordersPerDateB', 'revenuePerDateB']

# %% [markdown]
# Суммарное число заказов до выбранной даты включительно по группе A и по группе В.

# %%
ordersACummulative = ordersADaily.apply(
    lambda x: ordersADaily[ordersADaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateA': 'sum', 'revenuePerDateA': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersACummulative.columns = [
    'date',
    'ordersCummulativeA',
    'revenueCummulativeA',
]

# %%
ordersBCummulative = ordersBDaily.apply(
    lambda x: ordersBDaily[ordersBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateB': 'sum', 'revenuePerDateB': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersBCummulative.columns = [
    'date',
    'ordersCummulativeB',
    'revenueCummulativeB',
]

# %% [markdown]
# Совмещаем полученные результаты в одну таблицу.

# %%
data = (
    ordersADaily.merge(
        ordersBDaily, left_on='date', right_on='date', how='left'
    )
    .merge(ordersACummulative, left_on='date', right_on='date', how='left')
    .merge(ordersBCummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsADaily, left_on='date', right_on='date', how='left')
    .merge(visitorsBDaily, left_on='date', right_on='date', how='left')
    .merge(visitorsACummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsBCummulative, left_on='date', right_on='date', how='left')
)

# %%
data.head()
# Out:
#         date  ordersPerDateA  revenuePerDateA  ordersPerDateB  \
# 0 2019-08-01              24           148579              21
# 1 2019-08-02              20            93822              24
# 2 2019-08-03              24           112473              16
# 3 2019-08-04              16            70825              17
# 4 2019-08-05              25           124218              23
#
#    revenuePerDateB  ordersCummulativeA  revenueCummulativeA  \
# 0           101217                  24               148579
# 1           165531                  44               242401
# 2           114248                  68               354874
# 3           108571                  84               425699
# 4            92428                 109               549917
#
#    ordersCummulativeB  revenueCummulativeB  visitorsPerDateA  \
# 0                  21               101217               719
# 1                  45               266748               619
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Заново можно было и не собирать кумулятивные данные.  <br>
#
# Для расчета стат.значимости конверсии можно было, создавая переменную sample, "data['visitorsPerDateA'].sum()" заменить на сумму посещений по гр.А и аналогично с гр.В сделать) <br>
#
# </div>

# %% [markdown]
# ### Cтатистическая значимость различий в конверсии между группами по «сырым» данным.

# %% [markdown]
# Создадим переменные, в которых пользователи делали хотя бы 1 заказ, укажем число совершённых заказов.

# %%
ordersByUsersA = (
    orders[orders['group'] == 'A']
    .groupby('visitorid', as_index=False)
    .agg({'transactionid': pd.Series.nunique})
)
ordersByUsersA.columns = ['visitorid', 'orders']

# %%
ordersByUsersB = (
    orders[orders['group'] == 'B']
    .groupby('visitorid', as_index=False)
    .agg({'transactionid': pd.Series.nunique})
)
ordersByUsersB.columns = ['visitorid', 'orders']

# %% [markdown]
# Объявите переменные, в которых пользователям с заказами будет соответствовать число заказов пользователя. А пользователям без заказов — нули.

# %%
sampleA = pd.concat([
    ordersByUsersA['orders'],
    pd.Series(0,index=np.arange(data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])),
              name='orders')
],axis=0)


sampleB = pd.concat([
    ordersByUsersB['orders'],
    pd.Series(0, index=np.arange(data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])),
              name='orders')
],axis=0)

# %% [markdown]
# *Переменная **sampleA** хранит выборку, где каждый элемент — число заказов определённого пользователя, в том числе ноль. Значит, число элементов **sampleA** — это количество пользователей, сумма всех элементов — количество заказов. Чтобы получить конверсию в группе, поделим сумму заказов на число пользователей — найдём среднее в выборке **sampleA**. Аналогично все для **sampleB**.*

# %% [markdown]
# <div class="alert alert-block alert-danger"><b>Комментарий ревьюера</b>
#
# <s> <b>Ошибка:</b><br>
# Сформулируй, пожалуйста, **гипотезы ко всем тестам**.<br>
#     Мы должны знать, что отвергаем или не можем отвергнуть)<br>  </s>
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Комментарий студента</b>
#
# <b>Изменения:</b>  Сформулировал гипотезы))<br></div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера V-2</b>
#
# <b>Успех:</b><br>
#     👍Теперь мы знаем, что проверяем)
# </div>

# %% [markdown]
# **Сформулируем гипотезу** (на основе "сырых данных")
#
# * Нулевая: различий в конверсии между группами нет. (конверсия группы А = конверсии группы В)
# * Альтернативная: различия в конверсии между группами есть. (конверсия группы А ≠ конверсии группы В)

# %%
alpha = .05 # критический уровень статистической значимости

# %%
p_value = stats.mannwhitneyu(sampleA, sampleB)[1]

print('p-значение: ', "{0:.3f}".format(p_value))

if p_value < alpha:
    print('Отвергаем нулевую гипотезу: разница статистически значима')
else:
    print('Не получилось отвергнуть нулевую гипотезу, вывод о различии сделать нельзя')

print('Относительный прирост/проигрыш:',"{0:.3f}".format(sampleB.mean() / sampleA.mean() - 1))
# Out:
# p-значение:  0.017
# Отвергаем нулевую гипотезу: разница статистически значима
# Относительный прирост/проигрыш: 0.138

# %% [markdown]
# P-value меньше 0.05, потому **нулевую гипотезу отвергаем**. Анализ "сырых данных" сообщает, что **в конверсии между группами есть статистически значимые различия**. Относительный прирост конверсии группы B к к конверсии групп А равен **13.8%**.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍 Верно!
#
# </div>

# %% [markdown]
# ### Cтатистическая значимость различий в среднем чеке заказа между группами по «сырым» данным.

# %% [markdown]
# **Сформулируем гипотезу** (на основе "сырых данных")
#
# * Нулевая: различий в среднем чеке между группами нет. (средний чек группы А = среднему чеку группы В)
# * Альтернативная: различия в среднем чеке между группами есть. (средний чек группы А ≠ среднему чеку группы В)

# %%
p_value = stats.mannwhitneyu(orders[orders['group']=='A']['revenue'], orders[orders['group']=='B']['revenue'])[1]

print('p-значение: ', "{0:.3f}".format(p_value))

if p_value < alpha:
    print('Отвергаем нулевую гипотезу: разница статистически значима')
else:
    print('Не получилось отвергнуть нулевую гипотезу, вывод о различии сделать нельзя')

print('Относительный прирост/проигрыш:','{0:.3f}'.format(orders[orders['group']=='B']['revenue'].mean()/orders[orders['group']=='A']['revenue'].mean()-1))
# Out:
# p-значение:  0.729
# Не получилось отвергнуть нулевую гипотезу, вывод о различии сделать нельзя
# Относительный прирост/проигрыш: 0.259

# %% [markdown]
# P-value больше 0.05, потому **не получилось отвергнуть нулевую гипотезу**. Анализ "сырых данных" сообщает, что в конверсии **между группами нет статистически значимых отличий по среднему чеку**, но относительное различие среднего чека между сегментами составляет **25.9%**.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍 разница в 26% не является статистически значимой
#
# </div>

# %% [markdown]
# ###  Cтатистическую значимость различий в конверсии между группами по «очищенным» данным.

# %% [markdown]
# * 95-й и 99-й перцентили числа заказов на одного пользователя равны 2 и 4 заказам на пользователя.
# * 95-й и 99-й перцентили средних чеков равны 28000 и 53233 соответственно.
# * Примим за аномальных пользователей тех, кто совершил 4 заказа и более, или совершил заказ на сумму свыше 30 000 рублей. Так мы уберём 1% пользователей с наибольшим числом заказов и от 1% до 5% заказов с наибольшей стоимостью.

# %% [markdown]
# Аномальные пользователи.

# %%
usersWithManyOrders = pd.concat(
    [
        ordersByUsersA[ordersByUsersA['orders'] > np.percentile(ordersByUsers['transactionid'], [95, 99])[1]]['visitorid'],
        ordersByUsersB[ordersByUsersB['orders'] > np.percentile(ordersByUsers['transactionid'], [95, 99])[1]]['visitorid'],
    ],
    axis=0,
)

# %%
usersWithExpensiveOrders = orders[orders['revenue'] > np.percentile(orders['revenue'], [95, 99])[0]]['visitorid']
abnormalUsers = (
    pd.concat([usersWithManyOrders, usersWithExpensiveOrders], axis=0)
    .drop_duplicates()
    .sort_values()
)

abnormalUsers.head(5)
# Out:
# 1099    148427295
# 928     204675465
# 684     358944393
# 648     382846391
# 1189    393266494
# Name: visitorid, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-danger"><b>Комментарий ревьюера</b>
#
# <s> <b>Ошибка:</b><br>
# Михаил, при изменнии данных метод ручной записи цифр часто приводит к ошибкам - ты можешь забыть заменить цифры или ошибиться при вводе. Необходимо сделать код более отказоустойчивым. <br>
# <br>
# Например, можно сделать так:<br>
# revenu_max=np.percentile(orders['revenue'], [95, 99])[0] <br>
# usersWithExpensiveOrders = orders[orders['revenue'] > revenu_max]['visitorId']<br>
# И с кол-м заказов надо сделать также.<br>
#     Внеси, пожалуйста, поправки)  </s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Комментарий студента</b>
#
# <b>Изменения:</b> Исправил ручной ввод, действительно странно, что я его напечатал...<br></div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера V-2</b>
#
# <b>Успех:</b><br>
#     👍Теперь код стал отказоустойчивым)
# </div>

# %% [markdown]
# Подчищаем переменные, которые хранят число заказов определенного пользователя.

# %%
sampleAFiltered = pd.concat(
    [
        ordersByUsersA[
            np.logical_not(ordersByUsersA['visitorid'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

# %%
sampleBFiltered = pd.concat(
    [
        ordersByUsersB[
            np.logical_not(ordersByUsersB['visitorid'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

# %% [markdown]
# **Сформулируем гипотезу** (на основе "очищенных данных")
#
# * Нулевая: различий в конверсии между группами нет. (конверсия группы А = конверсии группы В)
# * Альтернативная: различия в конверсии между группами есть. (конверсия группы А ≠ конверсии группы В)

# %%
sampleAFiltered
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 18228    0
# 18229    0
# 18230    0
# 18231    0
# 18232    0
# Name: orders, Length: 18703, dtype: int64

# %%
p_value = stats.mannwhitneyu(sampleAFiltered, sampleBFiltered)[1]

print('p-значение: ', "{0:.3f}".format(p_value))

if p_value < alpha:
    print('Отвергаем нулевую гипотезу: разница статистически значима')
else:
    print('Не получилось отвергнуть нулевую гипотезу, вывод о различии сделать нельзя')

print('Относительный прирост/проигрыш:',"{0:.3f}".format(sampleBFiltered.mean()/sampleAFiltered.mean()-1))
# Out:
# p-значение:  0.018
# Отвергаем нулевую гипотезу: разница статистически значима
# Относительный прирост/проигрыш: 0.145

# %% [markdown]
# P-value меньше 0.05, потому **нулевую гипотезу отвергаем**. Анализ "очищенных данных" сообщает, что **в конверсии между группами есть статистически значимые различия**. Относительный прирост конверсии группы B к к конверсии групп А равен **14.4%**.

# %% [markdown]
# ### Cтатистическая значимость различий в среднем чеке заказа между группами по «очищенным» данным

# %% [markdown]
# **Сформулируем гипотезу** (на основе "очищенных данных")
#
# * Нулевая: различий в среднем чеке между группами нет. (средний чек группы А = среднему чеку группы В)
# * Альтернативная: различия в среднем чеке между группами есть. (средний чек группы А ≠ среднему чеку группы В)

# %%
p_value = stats.mannwhitneyu(
            orders[
                np.logical_and(
                    orders['group'] == 'A',
                    np.logical_not(orders['visitorid'].isin(abnormalUsers)),
                )
            ]['revenue'],
            orders[
                np.logical_and(
                    orders['group'] == 'B',
                    np.logical_not(orders['visitorid'].isin(abnormalUsers)),
                )
            ]['revenue'],
        )[1]

print('p-значение: ', "{0:.3f}".format(p_value))

if p_value < alpha:
    print('Отвергаем нулевую гипотезу: разница статистически значима')
else:
    print('Не получилось отвергнуть нулевую гипотезу, вывод о различии сделать нельзя')

print('Относительный прирост/проигрыш:',"{0:.3f}".format((
        orders[
            np.logical_and(
                orders['group'] == 'B',
                np.logical_not(orders['visitorid'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        / orders[
            np.logical_and(
                orders['group'] == 'A',
                np.logical_not(orders['visitorid'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        - 1
    )))
# Out:
# p-значение:  0.961
# Не получилось отвергнуть нулевую гипотезу, вывод о различии сделать нельзя
# Относительный прирост/проигрыш: -0.014

# %% [markdown]
# P-value больше 0.05, потому **не получилось отвергнуть нулевую гипотезу**. Анализ "очищенных данных" сообщает, что в **конверсии между группами нет статистически значимых отличий в среднем чеке**, но относительное различие среднего чека между сегментами составляет **1.7%**.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍 Все тесты проведены корректно!
#
# </div>

# %% [markdown]
# ### Доп. График кумулятивной выручки "очищенные" и "сырые" данные.

# %%
orders_new = orders[np.logical_not(orders['visitorid'].isin(abnormalUsers))]

# %%
datesGroups = orders_new[['date','group']].drop_duplicates()

# %%
ordersAggregated_new = datesGroups.apply(lambda x: orders_new[np.logical_and(orders_new['date'] <= x['date'], orders_new['group'] == x['group'])]\
.agg({'date' : 'max', 'group' : 'max', 'transactionid' : 'nunique', 'visitorid' : 'nunique', 'revenue' : 'sum'}), axis=1).sort_values(by=['date','group'])

# %%
cumulativeData_new = ordersAggregated_new.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulativeData_new.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

# %%
# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
cumulativeRevenueA_new = cumulativeData_new[cumulativeData_new['group']=='A'][['date','revenue', 'orders']]
# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
cumulativeRevenueB_new = cumulativeData_new[cumulativeData_new['group']=='B'][['date','revenue', 'orders']]

# %%
plt.figure(figsize=(12, 7))
# Строим график выручки группы А очищенная
plt.plot(cumulativeRevenueA_new['date'], cumulativeRevenueA_new['revenue'], label='A "очищенная"')
# Строим график выручки группы B очищенная
plt.plot(cumulativeRevenueB_new['date'], cumulativeRevenueB_new['revenue'], label='B "очищенная"')

# Строим график выручки группы А сырая
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')
# Строим график выручки группы B сырая
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')

plt.title('График кумулятивной выручки по группам на основе "чистых" и "грязных" данных', size = 13.5)
plt.xticks(rotation=90)
plt.legend() 
plt.show()

# %% [markdown]
# Как видим "очищенные" группы демонстрируют, тот же результат - что и "сырые" группы, с более выраженной стабильностью.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍
#
# </div>

# %% [markdown]
# ## Вывод

# %% [markdown]
# ### Общий вывод.

# %% [markdown]
# Анализ данных выявил, что между группами есть статистически значимые различия в конверсии. Относительный прирост конверсии группы В к конверсии группы А составил 14.4%.
# Так же анализ "сырых данных" сообщает, что в конверсии между группами нет статистически значимых отличий по среднему чеку, но относительное различие среднего чека между сегментами составляло - 25.9%, после "очистки данных" различие по чеку составило 1.7%. В данные просачиваются аномальные значеня.
# Так как конверсия группы В стабильно выше на протяжении 2/3 теста (непрерывно) и имеет большой размер куммулитивной выручки, решение: **Остановить тест, зафиксировать победу групп В**.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍 Решение принято! И оно верное!
#
# </div>

# %% [markdown]
# ### Промежуточные выводы.

# %% [markdown]
# *Фреймворк ICE и RICE*
#
# Охват клиентов вносит поправки в приоритеты гипотез. При ICE топ 3 гипотезы - 8, 0 и 7. При RICE - 7, 2 и 0.

# %% [markdown]
# *График кумулятивной выручки по группам*
#
# Выручка почти равномерно увеличивается в течение всего теста. Группа А растет постепенно, в то время как в группе В есть резкий рост в промежутке 17.08 - 21.08. Это сигнализирует о всплесках числа заказов, либо о появлении очень дорогих заказов в выборке.

# %% [markdown]
# *График кумулятивного среднего чека по группам*
#
# Средний чек увеличивается в течение всего теста. Однако, имеются имеются крупные чеки по каждой из групп (резкий рост на графике). Особенно выделяется группа В.

# %% [markdown]
# *График относительного изменения кумулятивного среднего чека группы B к группе A.*
#
# В нескольких точках график различия показывает, что и в начале теста есть аномальные чеки.

# %% [markdown]
# *График кумулятивной конверсии по группам.*
#
# Группы колебались в начале,но затем конверсия группы В вырвалась вперёд и зафиксировалась, конверсия группы А просела. Симметрично с большой натяжкой, после 18.08 числа.

# %% [markdown]
# *График относительного изменения кумулятивной конверсии группы B к группе A.*
#
# В начале теста группа B взяла разгон и стабильно опережает группу А. Конец недели показывает просадку, это говорит о влиянии аномалий.

# %% [markdown]
# *Точечный график количества заказов по пользователям*
#
# * Есть пользователи, которые совершали 5, 8, 9 и 11 заказов. Значительно больше, чем обычный пользователь за неделю.
# * Большинство покупателей заказывали только один раз. Однако доля пользователей с 2-4 заказами тоже значительна.
# * Выводы подтверждаются: много пользователей с 2-4 заказами. Их точная доля не ясна — непонятно, считать их аномалиями или нет.

# %% [markdown]
# *95-й и 99-й перцентили количества заказов на пользователя.*
#
# Не более 5% совершали более двух заказов. И не более 1% пользователей - больше четырех заказов.

# %% [markdown]
# *Точечный график стоимостей заказов*
#
# * Сумма большинства заказов не превышает 200000
# * Точечный график подтверждает, что у группы В средний чек и выручка увеличивается за счет одного заказа.

# %% [markdown]
# *95-й и 99-й перцентили стоимости заказов.*
#
# Не более, чем у 5% заказов чек дороже 28000. И не больше, чем у 1% заказов - дороже 58234.

# %% [markdown]
# *Cтатистическая значимость различий в конверсии между группами по «сырым» данным.*
#
# P-value меньше 0.05, потому **нулевую гипотезу отвергаем**. Анализ "сырых данных" сообщает, что в конверсии между группами **есть статистически значимые различия**. Относительный прирост конверсии группы B к к конверсии групп А равен **13.8%**.

# %% [markdown]
# *Cтатистическая значимость различий в среднем чеке заказа между группами по «сырым» данным.*
#
# P-value больше 0.05, потому **не получилось отвергнуть нулевую гипотезу**. Анализ "сырых данных" сообщает, что в **конверсии между группами нет статистически значимых отличий в среднем чеке**, но относительное различие среднего чека между сегментами составляет **25.9%**.

# %% [markdown]
# *Cтатистическую значимость различий в конверсии между группами по «очищенным» данным*
#
# P-value меньше 0.05, потому **нулевую гипотезу отвергаем**. Анализ "очищенных данных" сообщает, что **в конверсии между группами есть статистически значимые различия**. Относительный прирост конверсии группы B к конверсии группы А равен **14.4%**.

# %% [markdown]
# *Cтатистическая значимость различий в среднем чеке заказа между группами по «очищенным» данным*
#
# P-value больше 0.05, потому **не получилось отвергнуть нулевую гипотезу**. Анализ "очищенных данных" сообщает, что в **конверсии между группами нет статистически значимых отличий по среднему чеку**, но относительное различие среднего чека между сегментами составляет **1.7%**.

# %% [markdown]
# <div style="background: #cceeaa; padding: 5px; border: 1px solid green; border-radius: 5px;">
# <font color='green'>
#     <b><u>Общий вывод по проекту</u></b>
# <font color='green'><br>
#
#
# Михаил, было интересно проверять твой проект! Уверенная работа, на мой взгляд) Приложено много усилий, ты - молодец! Есть несколько важных моментов, которые я отметила и которые можно было бы улучшить, подсказки ты найдешь в моих комментариях.
#
# **Что мне особенно понравилось в твоей работе:**:
#
# * Тесты проведены корректно!
# * Выводы детальные и вдумчивые!
# * Код логичный и понятный.
# * Проект полностью соответствует плану!
# * По итогам АВ теста принято решение!
#
# **На что стоит обратить внимание**:
#
# * Осталось совсем немного поправить, а именно: сформулировать гипотезы где их не хватает, заменить числа в коде переменными. Подсказки ты найдешь в моих комментариях.
#
#
#
#
# **Доработка займет у тебя совсем немного времени) Желаю удачи и жду твой проект на повторное ревью!**😉

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Комментарий студента</b>
#
# Переживал, что получится кривой результат, а тут даже и "попал". Большое спасибо за проверку, притензии нет, все хорошо!)) Понравился график "ICE and RICE гипотезы".

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера V-2</b>
#
# <b>Успех:</b><br>
#     👍Еще как попал! А график действительно удобный, особенно, когда много гипотез)
# </div>
